# %% [markdown]
# # Clasificación de sentimiento: Preprocesado de los datos
# En esta celda, vamos a preparar los datos del modelo para poder entrenar el modelo en el siguiente notebook.
# Los pasos que seguiremos son:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Abrimos el dataset
from sklearn.model_selection import train_test_split
import pandas as pd
path = "data/dataset_riesgo_limpio.csv"
import pandas as pd
df = pd.read_csv(path)
# Separamos las características (X) y la variable objetivo (y)
X = df["descripcion"]
y = df["etiqueta"]


# Imprimimos las formas de los conjuntos de entrenamiento y prueba
print("Conjunto:", X.shape, y.shape)
# Out:
# Conjunto: (300,) (300,)
